# %% [markdown]
# <a href="https://colab.research.google.com/github/flydancetolhs/My_colab/blob/main/11110601_colab_install_package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
nb_path= '/content/notebooks'
os.symlink('/content/gdrive/MyDrive/Colab Notebooks/python_package', nb_path)
sys.path.insert(0, nb_path)

# %%
# !pip install --target=/content/notebooks streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached streamlit-1.9.2-py2.py3-none-any.whl (10.1 MB)
# ...
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# ...
#   Using cached pyarrow-8.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.3 MB)
# ...
#   Using cached validators-0.19.0-py3-none-any.whl
# ...
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# ...
#   Using cached Pillow-9.1.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# ...
#   Using cached click-8.0.4-py3-none-any.whl (97 kB)
# ...
#   Using cached typing_extensions-4.2.0-py3-none-any.whl (24 kB)
# ...
#   Using cached cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# ...
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached protobuf-3.20.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# ...
#   Using cached GitPython-3.1.27-py3-none-any.whl (181 kB)
# ...
